# %%
import seaborn as sns 
titanic = sns.load_dataset('titanic')

# %%
titanic.head(50)
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.0      1      0    7.2500        S   Third
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 2          1       3  female  26.0      0      0    7.9250        S   Third
# 3          1       1  female  35.0      1      0   53.1000        S   First
# 4          0       3    male  35.0      0      0    8.0500        S   Third
# 5          0       3    male   NaN      0      0    8.4583        Q   Third
# 6          0       1    male  54.0      0      0   51.8625        S   First
# 7          0       3    male   2.0      3      1   21.0750        S   Third
# 8          1       3  female  27.0      0      2   11.1333        S   Third
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
titanic.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %%
titanic.sample(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 275         1       1  female  63.0      1      0  77.9583        S  First
# 739         0       3    male   NaN      0      0   7.8958        S  Third
# 702         0       3  female  18.0      0      1  14.4542        C  Third
# 591         1       1  female  52.0      1      0  78.2667        C  First
# 709         1       3    male   NaN      1      1  15.2458        C  Third
# 493         0       1    male  71.0      0      0  49.5042        C  First
# 849         1       1  female   NaN      1      0  89.1042        C  First
# 60          0       3    male  22.0      0      0   7.2292        C  Third
# 61          1       1  female  38.0      0      0  80.0000      NaN  First
# 320         0       3    male  22.0      0      0   7.2500        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 275  woman       False    D  Southampton   yes  False
# ...

# %%
titanic.isna().sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
titanic.describe(include='O')
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
titanic.describe(include='category')
# Out:
#         class deck
# count     891  203
# unique      3    7
# top     Third    C
# freq      491   59

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# methods = pd.series(dir(pd))
# methods[methods.str.contains('read')]

# %%
import pandas as pd
methods = pd.Series(dir(pd)) 
methods[methods.str.contains('read')]
# Out:
# 106    read_clipboard
# 107          read_csv
# 108        read_excel
# 109      read_feather
# 110          read_fwf
# 111          read_gbq
# 112          read_hdf
# 113         read_html
# 114         read_json
# 115          read_orc
# 116      read_parquet
# 117       read_pickle
# 118          read_sas
# 119         read_spss
# 120          read_sql
# 121    read_sql_query
# 122    read_sql_table
# 123        read_stata
# 124        read_table
# 125          read_xml
# dtype: object

# %%
titanic.loc[0, 'age']
# Out:
# 22.0

# %%
titanic.loc[:,'age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
titanic.loc[9,:]
# Out:
# survived               1
# pclass                 2
# sex               female
# age                 14.0
# sibsp                  1
# parch                  0
# fare             30.0708
# embarked               C
# class             Second
# who                child
# adult_male         False
# deck                 NaN
# embark_town    Cherbourg
# alive                yes
# alone              False
# Name: 9, dtype: object

# %%
titanic.loc[4:9,:]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
titanic.iloc[4:9,:]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
# 7         0       3    male   2.0      3      1  21.0750        S  Third
# 8         1       3  female  27.0      0      2  11.1333        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False

# %%
titanic[titanic.loc[:,'pclass']==1].sort_values(['fare', 'age']).head(5)
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 822         0       1  male  38.0      0      0   0.0        S  First  man
# 806         0       1  male  39.0      0      0   0.0        S  First  man
# 263         0       1  male  40.0      0      0   0.0        S  First  man
# 633         0       1  male   NaN      0      0   0.0        S  First  man
# 815         0       1  male   NaN      0      0   0.0        S  First  man
#
#      adult_male deck  embark_town alive  alone
# 822        True  NaN  Southampton    no   True
# 806        True    A  Southampton    no   True
# 263        True    B  Southampton    no   True
# 633        True  NaN  Southampton    no   True
# 815        True    B  Southampton    no   True

# %%
titanic['cpya'] = titanic.loc[:,'fare'] / titanic.loc[:,'age']

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#              cpya
# count  714.000000
# mean     2.391841
# std      8.115102
# min      0.000000
# 25%      0.342403
# 50%      0.565217
# 75%      1.673857
# max    164.728261

# %%
titanic.sort_values('cpya',ascending=False).head()
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 305         1       1    male  0.92      1      2  151.5500        S   First
# 297         0       1  female  2.00      1      2  151.5500        S   First
# 386         0       3    male  1.00      5      2   46.9000        S   Third
# 164         0       3    male  1.00      4      1   39.6875        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone        cpya
# 305  child       False    C  Southampton   yes  False  164.728261
# 297  child       False    C  Southampton    no  False   75.775000
# 386  child       False  NaN  Southampton    no  False   46.900000
# 164  child       False  NaN  Southampton    no  False   39.687500
# 183  child       False    F  Southampton   yes  False   39.000000

# %%
titanic.groupby('class').mean()
# Out:
#         survived  pclass        age     sibsp     parch       fare  \
# class
# First   0.629630     1.0  38.233441  0.416667  0.356481  84.154687
# Second  0.472826     2.0  29.877630  0.402174  0.380435  20.662183
# Third   0.242363     3.0  25.140620  0.615071  0.393075  13.675550
#
#         adult_male     alone      cpya
# class
# First     0.550926  0.504630  4.189522
# Second    0.538043  0.565217  2.088590
# Third     0.649695  0.659878  1.597739
