# %%
import requests

# %%
#  url 

url='https://api.data.gov/ed/collegescorecard/v1/schools?school.name=boston%20college&api_key=j8HThx6F8kOm9gBm7OzuzqmYcj3HfGxfsACoP72O'

# %%
# Using get command to get the response

result = requests.get(url)

# %%
result.statuscode
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/17/4rz5trnj77755dwwrs7kt4dw0000gn/T/ipykernel_1059/2379550232.py in <module>
# ----> 1 result.statuscode
#
# AttributeError: 'Response' object has no attribute 'statuscode'

# %%
result.status_code
# Out:
# 200

# %%
result.headers
# Out:
# {'Date': 'Wed, 09 Mar 2022 02:48:33 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding, Accept-Encoding, Origin', 'X-RateLimit-Limit': '1000', 'X-RateLimit-Remaining': '999', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Headers': 'Content-Type, Authorization, X-Requested-With', 'Access-Control-Allow-Methods': 'POST, GET, OPTIONS, PUT, DELETE', 'Access-Control-Allow-Origin': '*', 'Access-Control-Max-Age': '86400', 'Cache-Control': 'no-cache, private', 'X-Vcap-Request-Id': 'a32432c8-7fd1-4ce8-76f9-7fde3447e83d', 'X-Frame-Options': 'DENY', 'Strict-Transport-Security': 'max-age=31536000, max-age=31536000; preload', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Content-Encoding': 'gzip', 'Age': '0', 'Via': 'https/1.1 api-umbrella (ApacheTrafficServer [cMsSf ])', 'X-Cache': 'MISS'}

# %%
result
# Out:
# <Response [200]>

# %%
result.text
# Out:
# '{"metadata":{"page":0,"total":4,"per_page":20},"results":[{"latest":{"school":{"zip":"02115-2703","city":"Boston","name":"Boston Architectural College","alias":"Boston Architectural Center","state":"MA","locale":11,"dolflag":0,"branches":1,"men_only":0,"operating":1,"ownership":2,"region_id":1,"accreditor":"New England Commission on Higher Education","school_url":"www.the-bac.edu\\/","state_fips":25,"women_only":0,"main_campus":1,"online_only":0,"endowment":{"end":11715986,"begin":11840710},"carnegie_basic":30,"faculty_salary":5868,"ownership_peps":2,"accreditor_code":"NECHE","ft_faculty_rate":0.1182,"carnegie_undergrad":11,"degree_urbanization":null,"under_investigation":0,"price_calculator_url":"www.the-bac.edu\\/admissions-and-financial-aid\\/financial-aid\\/net-price-calculator","carnegie_size_setting":6,"minority_serving":{"annh":0,"nant":0,"aanipi":0,"tribal":0,"hispanic":0,"historically_black":0,"predominantly_black":0},"religious_affiliation":null,"open_admissions_policy":1,
# ...

# %%
result.json()
# Out:
# {'metadata': {'page': 0, 'total': 4, 'per_page': 20},
#  'results': [{'latest': {'school': {'zip': '02115-2703',
#      'city': 'Boston',
#      'name': 'Boston Architectural College',
#      'alias': 'Boston Architectural Center',
#      'state': 'MA',
#      'locale': 11,
#      'dolflag': 0,
#      'branches': 1,
#      'men_only': 0,
#      'operating': 1,
#      'ownership': 2,
#      'region_id': 1,
#      'accreditor': 'New England Commission on Higher Education',
#      'school_url': 'www.the-bac.edu/',
#      'state_fips': 25,
#      'women_only': 0,
#      'main_campus': 1,
#      'online_only': 0,
#      'endowment': {'end': 11715986, 'begin': 11840710},
#      'carnegie_basic': 30,
#      'faculty_salary': 5868,
#      'ownership_peps': 2,
#      'accreditor_code': 'NECHE',
#      'ft_faculty_rate': 0.1182,
#      'carnegie_undergrad': 11,
#      'degree_urbanization': None,
#      'under_investigation': 0,
# ...

# %%
import requests
from bs4 import BeautifulSoup
