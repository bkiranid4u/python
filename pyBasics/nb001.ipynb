# %%
def foo(name, **kwargs) {
    print(name)
    print('Value from *kwargs',kwargs['name'])

foo(name='Kiran', **{'name':'Srinika'})
# Out:
#   File "<ipython-input-1-ea1926b53ae2>", line 1
#     def foo(name, **kwargs) {
#                             ^
# SyntaxError: invalid syntax
